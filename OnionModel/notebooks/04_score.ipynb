# %%
from ultralytics import YOLO

model = YOLO(r"D:\SIH26031\OnionModel\results\onion_segmentation_final\weights\best.pt")  # your trained Model 1

metrics = model.val(data=r"D:\SIH26031\OnionModel\datasets\onion_segmentation\data.yaml", split="test")
# Out:
# Ultralytics 8.4.138  Python-3.14.6 torch-2.13.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO11n-seg summary (fused): 114 layers, 2,834,958 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access  (ping: 0.10.1 ms, read: 728.8289.6 MB/s, size: 1556.6 KB)
# val: Scanning D:\SIH26031\OnionModel\datasets\onion_segmentation\test\labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 2.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                    all         10        103      0.995      0.999      0.995      0.925      0.995      0.999      0.995      0.874
#                   coin         10         10      0.989          1      0.995      0.924      0.989          1      0.995      0.831
# ...

# %%
metrics = model.val(data=r"D:\SIH26031\OnionModel\datasets\onion_segmentation\data.yaml", split="test")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP50-95: {metrics.box.map}")
print(f"Mask mAP50-95: {metrics.seg.map}")
# Out:
# Ultralytics 8.4.138  Python-3.14.6 torch-2.13.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# val: Fast image access  (ping: 0.00.0 ms, read: 2104.5879.1 MB/s, size: 1377.6 KB)
# val: Scanning D:\SIH26031\OnionModel\datasets\onion_segmentation\test\labels.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 471.3Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all         10        103      0.995      0.999      0.995      0.925      0.995      0.999      0.995      0.874
#                   coin         10         10      0.989          1      0.995      0.924      0.989          1      0.995      0.831
#                  onion         10         93          1      0.998      0.995      0.927          1      0.998      0.995      0.916
# ...
